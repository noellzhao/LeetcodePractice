# %% [markdown]
# # 49 Group Anagrams

# %% [markdown]
# Idea:
# 1.

# %%
from collections import defaultdict
groups = defaultdict(list)

# %%
groups['a'].append('ddd')

# %%
type((0,1,2,3))
# Out:
# tuple
