# %% [markdown]
# # 347 Top K Frequent Elements

# %%
nums = [1,2,1,2,1,2,3,1,3,2]
k = 2

# %%
lookup = {}
for num in nums:
    if num in lookup:
        lookup[num]+=1
    else:
        lookup[num] = 1
lookup
# Out:
# {1: 4, 2: 4, 3: 2}

# %%
buckets = [[] for _ in range(len(nums)+1)]
buckets
